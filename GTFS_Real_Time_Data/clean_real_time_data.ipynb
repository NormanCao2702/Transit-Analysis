# %%
# Libraries
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# %%
# Constant Variables
# Filenames
EXTRACTED_REAL_TIME_DATA_FILENAME = 'extracted_real_time_data.json'
CLEANED_REAL_TIME_DATA_FILENAME = 'cleaned_real_time_data.json'

# %%
# Read the data frame from a json file
df = pd.read_json(EXTRACTED_REAL_TIME_DATA_FILENAME, dtype={'RecordedDate': 'str'})
df
# Out:
#        VehicleNo    TripId RouteNo Direction                    Destination  \
# 0          16026  13678409     144     NORTH                            SFU
# 1          16026  13678409     144     NORTH                            SFU
# 2          16026  13678409     144     NORTH                            SFU
# 3          16026  13678409     144     NORTH                            SFU
# 4          16026  13678409     144     NORTH                            SFU
# ...          ...       ...     ...       ...                            ...
# 62767      19045  13717155      R5      EAST  HASTINGS ST / TO SFU EXCHANGE
# 62768      22012  13717325      R5      WEST   HASTINGS ST / TO BURRARD STN
# 62769       8126  13717184      R5      EAST  HASTINGS ST / TO SFU EXCHANGE
# 62770       8134  13717218      R5      EAST  HASTINGS ST / TO SFU EXCHANGE
# 62771       8141  13717219      R5      EAST  HASTINGS ST / TO SFU EXCHANGE
#
#       Pattern   Latitude   Longitude RecordedTime  \
# ...

# %%
# Convert the date and time strings to datetime
def convert_to_datetime(date, time):
    return datetime.strptime(date + time, '%Y%m%d%I:%M:%S %p')
df['RecordedDateTime'] = df.apply(lambda row: convert_to_datetime(row['RecordedDate'], row['RecordedTime']), axis=1)
df
# Out:
#        VehicleNo    TripId RouteNo Direction                    Destination  \
# 0          16026  13678409     144     NORTH                            SFU
# 1          16026  13678409     144     NORTH                            SFU
# 2          16026  13678409     144     NORTH                            SFU
# 3          16026  13678409     144     NORTH                            SFU
# 4          16026  13678409     144     NORTH                            SFU
# ...          ...       ...     ...       ...                            ...
# 62767      19045  13717155      R5      EAST  HASTINGS ST / TO SFU EXCHANGE
# 62768      22012  13717325      R5      WEST   HASTINGS ST / TO BURRARD STN
# 62769       8126  13717184      R5      EAST  HASTINGS ST / TO SFU EXCHANGE
# 62770       8134  13717218      R5      EAST  HASTINGS ST / TO SFU EXCHANGE
# 62771       8141  13717219      R5      EAST  HASTINGS ST / TO SFU EXCHANGE
#
#       Pattern   Latitude   Longitude RecordedTime  \
# ...

# %%
# Drop the unused columns
df.drop(['VehicleNo', 'TripId', 'Destination', 'Pattern', 'RecordedTime', 'RouteMap', 'RecordedDate'], axis=1, inplace=True)
df
# Out:
#       RouteNo Direction   Latitude   Longitude    RecordedDateTime
# 0         144     NORTH  49.225617 -123.004250 2024-04-07 06:58:07
# 1         144     NORTH  49.225617 -123.003483 2024-04-07 06:59:07
# 2         144     NORTH  49.225150 -123.002100 2024-04-07 07:00:07
# 3         144     NORTH  49.224100 -122.999983 2024-04-07 07:01:43
# 4         144     NORTH  49.224367 -122.997567 2024-04-07 07:02:24
# ...       ...       ...        ...         ...                 ...
# 62767      R5      EAST  49.280067 -122.919800 2024-04-09 23:36:20
# 62768      R5      WEST  49.280450 -122.958483 2024-04-09 23:36:40
# 62769      R5      EAST  49.282250 -123.108483 2024-04-09 23:35:55
# 62770      R5      EAST  49.280233 -122.992467 2024-04-09 23:36:26
# 62771      R5      EAST  49.279050 -122.912283 2024-04-09 23:22:16
#
# [62772 rows x 5 columns]

# %%
# Drop all null values
df.dropna(axis=1, inplace=True)
df
# Out:
#       RouteNo Direction   Latitude   Longitude    RecordedDateTime
# 0         144     NORTH  49.225617 -123.004250 2024-04-07 06:58:07
# 1         144     NORTH  49.225617 -123.003483 2024-04-07 06:59:07
# 2         144     NORTH  49.225150 -123.002100 2024-04-07 07:00:07
# 3         144     NORTH  49.224100 -122.999983 2024-04-07 07:01:43
# 4         144     NORTH  49.224367 -122.997567 2024-04-07 07:02:24
# ...       ...       ...        ...         ...                 ...
# 62767      R5      EAST  49.280067 -122.919800 2024-04-09 23:36:20
# 62768      R5      WEST  49.280450 -122.958483 2024-04-09 23:36:40
# 62769      R5      EAST  49.282250 -123.108483 2024-04-09 23:35:55
# 62770      R5      EAST  49.280233 -122.992467 2024-04-09 23:36:26
# 62771      R5      EAST  49.279050 -122.912283 2024-04-09 23:22:16
#
# [62772 rows x 5 columns]

# %%
# Drop all duplicates
df.drop_duplicates(inplace=True)
df
# Out:
#       RouteNo Direction   Latitude   Longitude    RecordedDateTime
# 0         144     NORTH  49.225617 -123.004250 2024-04-07 06:58:07
# 1         144     NORTH  49.225617 -123.003483 2024-04-07 06:59:07
# 2         144     NORTH  49.225150 -123.002100 2024-04-07 07:00:07
# 3         144     NORTH  49.224100 -122.999983 2024-04-07 07:01:43
# 4         144     NORTH  49.224367 -122.997567 2024-04-07 07:02:24
# ...       ...       ...        ...         ...                 ...
# 62766      R5      WEST  49.281233 -123.091633 2024-04-09 23:35:52
# 62767      R5      EAST  49.280067 -122.919800 2024-04-09 23:36:20
# 62768      R5      WEST  49.280450 -122.958483 2024-04-09 23:36:40
# 62769      R5      EAST  49.282250 -123.108483 2024-04-09 23:35:55
# 62770      R5      EAST  49.280233 -122.992467 2024-04-09 23:36:26
#
# [52571 rows x 5 columns]

# %%
# Filter the recorded hour bewteen 7:00 to 23:00
df = df[(df['RecordedDateTime'].dt.hour >= 7) & (df['RecordedDateTime'].dt.hour < 23)]
df
# Out:
#       RouteNo Direction   Latitude   Longitude    RecordedDateTime
# 2         144     NORTH  49.225150 -123.002100 2024-04-07 07:00:07
# 3         144     NORTH  49.224100 -122.999983 2024-04-07 07:01:43
# 4         144     NORTH  49.224367 -122.997567 2024-04-07 07:02:24
# 5         144     NORTH  49.225700 -122.994100 2024-04-07 07:03:23
# 6         144     NORTH  49.229850 -122.992800 2024-04-07 07:04:45
# ...       ...       ...        ...         ...                 ...
# 62508      R5      EAST  49.285700 -123.114283 2024-04-09 22:59:26
# 62509      R5      EAST  49.276733 -122.944833 2024-04-09 22:59:37
# 62510      R5      WEST  49.281050 -123.000083 2024-04-09 22:59:08
# 62511      R5      WEST  49.285333 -123.115900 2024-04-09 22:59:37
# 62512      R5      EAST  49.281050 -123.043017 2024-04-09 22:59:22
#
# [51308 rows x 5 columns]

# %%
# Filter the recorded date bewteen April 7 to April 9
df = df[(df['RecordedDateTime'].dt.day >= 7) & (df['RecordedDateTime'].dt.day <= 9)]
df
# Out:
#       RouteNo Direction   Latitude   Longitude    RecordedDateTime
# 2         144     NORTH  49.225150 -123.002100 2024-04-07 07:00:07
# 3         144     NORTH  49.224100 -122.999983 2024-04-07 07:01:43
# 4         144     NORTH  49.224367 -122.997567 2024-04-07 07:02:24
# 5         144     NORTH  49.225700 -122.994100 2024-04-07 07:03:23
# 6         144     NORTH  49.229850 -122.992800 2024-04-07 07:04:45
# ...       ...       ...        ...         ...                 ...
# 62508      R5      EAST  49.285700 -123.114283 2024-04-09 22:59:26
# 62509      R5      EAST  49.276733 -122.944833 2024-04-09 22:59:37
# 62510      R5      WEST  49.281050 -123.000083 2024-04-09 22:59:08
# 62511      R5      WEST  49.285333 -123.115900 2024-04-09 22:59:37
# 62512      R5      EAST  49.281050 -123.043017 2024-04-09 22:59:22
#
# [51308 rows x 5 columns]

# %%
# Get the unique values of RouteNo
df['RouteNo'].unique()
# Out:
# array([144, 145, 'R5'], dtype=object)

# %%
# Get the unique values of Direction
df['Direction'].unique()
# Out:
# array(['NORTH', 'SOUTH', 'WEST', 'EAST'], dtype=object)

# %%
# Get the stats of the data frame
df.describe()
# Out:
#            Latitude     Longitude
# count  51308.000000  51308.000000
# mean      49.180676   -122.758841
# std        2.107085      5.314024
# min        0.000000   -123.120783
# 25%       49.263167   -123.044221
# 50%       49.279467   -122.969167
# 75%       49.281133   -122.920850
# max       49.288350      0.000000

# %%
# Plot the graph of Latitude
plt.title('Boxplot of Latitude')
plt.boxplot(df['Latitude'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2c582100b50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2c582107150>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2c582107910>],
#  'medians': [<matplotlib.lines.Line2D at 0x2c5821117d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2c582111b10>],
#  'means': []}

# %%
# Plot the graph of Longitude
plt.title('Boxplot of Longitude')
plt.boxplot(df['Longitude'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2c5821717d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2c582176810>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2c582170b90>],
#  'medians': [<matplotlib.lines.Line2D at 0x2c582174290>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2c5821298d0>],
#  'means': []}

# %%
# Remove all outliers of Latitude
latitude_head = df['Latitude'].quantile(0.01)
latitude_tail = df['Latitude'].quantile(0.99)
df = df[(df['Latitude'] >= latitude_head) & (df['Latitude'] <= latitude_tail)]
df
# Out:
#       RouteNo Direction   Latitude   Longitude    RecordedDateTime
# 2         144     NORTH  49.225150 -123.002100 2024-04-07 07:00:07
# 5         144     NORTH  49.225700 -122.994100 2024-04-07 07:03:23
# 6         144     NORTH  49.229850 -122.992800 2024-04-07 07:04:45
# 7         144     NORTH  49.229650 -122.987017 2024-04-07 07:05:43
# 8         144     NORTH  49.229450 -122.975800 2024-04-07 07:06:43
# ...       ...       ...        ...         ...                 ...
# 62508      R5      EAST  49.285700 -123.114283 2024-04-09 22:59:26
# 62509      R5      EAST  49.276733 -122.944833 2024-04-09 22:59:37
# 62510      R5      WEST  49.281050 -123.000083 2024-04-09 22:59:08
# 62511      R5      WEST  49.285333 -123.115900 2024-04-09 22:59:37
# 62512      R5      EAST  49.281050 -123.043017 2024-04-09 22:59:22
#
# [50297 rows x 5 columns]

# %%
# Remove all outliers of Longitude
longitude_head = df['Longitude'].quantile(0.01)
longitude_tail = df['Longitude'].quantile(0.99)
df = df[(df['Longitude'] >= longitude_head) & (df['Longitude'] <= longitude_tail)]
df
# Out:
#       RouteNo Direction   Latitude   Longitude    RecordedDateTime
# 2         144     NORTH  49.225150 -123.002100 2024-04-07 07:00:07
# 5         144     NORTH  49.225700 -122.994100 2024-04-07 07:03:23
# 6         144     NORTH  49.229850 -122.992800 2024-04-07 07:04:45
# 7         144     NORTH  49.229650 -122.987017 2024-04-07 07:05:43
# 8         144     NORTH  49.229450 -122.975800 2024-04-07 07:06:43
# ...       ...       ...        ...         ...                 ...
# 62508      R5      EAST  49.285700 -123.114283 2024-04-09 22:59:26
# 62509      R5      EAST  49.276733 -122.944833 2024-04-09 22:59:37
# 62510      R5      WEST  49.281050 -123.000083 2024-04-09 22:59:08
# 62511      R5      WEST  49.285333 -123.115900 2024-04-09 22:59:37
# 62512      R5      EAST  49.281050 -123.043017 2024-04-09 22:59:22
#
# [49308 rows x 5 columns]

# %%
# Plot the graph of Latitude
plt.title('Boxplot of Latitude')
plt.boxplot(df['Latitude'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2c58671ac90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2c586722790>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2c5866f5750>],
#  'medians': [<matplotlib.lines.Line2D at 0x2c586722010>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2c586709190>],
#  'means': []}

# %%
# Plot the graph of Longitude
plt.title('Boxplot of Longitude')
plt.boxplot(df['Longitude'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2c58675d610>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2c58675fe90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2c58675c310>],
#  'medians': [<matplotlib.lines.Line2D at 0x2c586764790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2c58675ff10>],
#  'means': []}

# %%
# Save the cleaned real time data frame
df.to_json(CLEANED_REAL_TIME_DATA_FILENAME, orient='records')

# %%
df
# Out:
#       RouteNo Direction   Latitude   Longitude    RecordedDateTime
# 2         144     NORTH  49.225150 -123.002100 2024-04-07 07:00:07
# 5         144     NORTH  49.225700 -122.994100 2024-04-07 07:03:23
# 6         144     NORTH  49.229850 -122.992800 2024-04-07 07:04:45
# 7         144     NORTH  49.229650 -122.987017 2024-04-07 07:05:43
# 8         144     NORTH  49.229450 -122.975800 2024-04-07 07:06:43
# ...       ...       ...        ...         ...                 ...
# 62508      R5      EAST  49.285700 -123.114283 2024-04-09 22:59:26
# 62509      R5      EAST  49.276733 -122.944833 2024-04-09 22:59:37
# 62510      R5      WEST  49.281050 -123.000083 2024-04-09 22:59:08
# 62511      R5      WEST  49.285333 -123.115900 2024-04-09 22:59:37
# 62512      R5      EAST  49.281050 -123.043017 2024-04-09 22:59:22
#
# [49308 rows x 5 columns]
